# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
from sklearn.linear_model import LinearRegression
from datetime import datetime
lr = LinearRegression()

df = pd.read_csv("Data/nfl_pass_rush_receive_raw_data.csv", header = 0)
df.drop(['player_id', 'Vegas_Line', 'Vegas_Favorite', 'Over_Under'], inplace=True, axis=1)
df
# Out:
#             game_id pos                    player team  pass_cmp  pass_att  \
# 0      201909050chi  QB             Aaron Rodgers  GNB        18        30
# 1      201909050chi  RB               Aaron Jones  GNB         0         0
# 2      201909050chi  WR  Marquez Valdes-Scantling  GNB         0         0
# 3      201909050chi  WR             Davante Adams  GNB         0         0
# 4      201909050chi  TE              Jimmy Graham  GNB         0         0
# ...             ...  ..                       ...  ...       ...       ...
# 19968  202202130cin  WR            Brandon Powell  LAR         0         0
# 19969  202202130cin  RB              Buddy Howell  LAR         0         0
# 19970  202202130cin  TE               Drew Sample  CIN         0         0
# 19971  202202130cin  WR              Trent Taylor  CIN         0         0
# 19972  202202130cin  TE           Mitchell Wilcox  CIN         0         0
#
# ...

# %%
df['game_date'] = pd.to_datetime(df.game_date)
start_21 = '9/9/2021'
end_21 = '1/9/2022'
mask = (df['game_date'] >= start_21) & (df['game_date'] <= end_21)
df.loc[mask]
# Out:
#             game_id pos            player team  pass_cmp  pass_att  pass_yds  \
# 12960  202109090tam  QB      Dak Prescott  DAL        42        58       403
# 12961  202109090tam  RB   Ezekiel Elliott  DAL         0         0         0
# 12962  202109090tam  RB      Tony Pollard  DAL         0         0         0
# 12963  202109090tam  WR      Amari Cooper  DAL         0         0         0
# 12964  202109090tam  WR       CeeDee Lamb  DAL         0         0         0
# ...             ...  ..               ...  ...       ...       ...       ...
# 19667  202201090tam  TE        Ian Thomas  CAR         0         0         0
# 19668  202201090tam  TE  Stephen Sullivan  CAR         0         0         0
# 19669  202201090tam  WR     Cyril Grayson  TAM         0         0         0
# 19670  202201090tam  TE       O.J. Howard  TAM         0         0         0
# 19671  202201090tam  TE      Darren Fells  TAM         0         0         0
#
# ...

# %%
len(df.loc[mask])
# Out:
# 6712

# %%
start_20 = '9/10/2020'
end_20 = '1/3/2021'
mask = (df['game_date'] >= start_20) & (df['game_date'] <= end_20)
df.loc[mask]
# Out:
#             game_id pos           player team  pass_cmp  pass_att  pass_yds  \
# 6330   202009100kan  QB   Deshaun Watson  HOU        20        32       253
# 6331   202009100kan  RB    David Johnson  HOU         0         0         0
# 6332   202009100kan  RB     Duke Johnson  HOU         0         0         0
# 6333   202009100kan  WR      Will Fuller  HOU         0         0         0
# 6334   202009100kan  TE     Jordan Akins  HOU         0         0         0
# ...             ...  ..              ...  ...       ...       ...       ...
# 12645  202101030tam  TE   Antony Auclair  TAM         0         0         0
# 12646  202101030tam  WR   Jaydon Mickens  TAM         0         0         0
# 12647  202101030tam  RB  Ke'Shawn Vaughn  TAM         0         0         0
# 12648  202101030tam  TE    Cameron Brate  TAM         0         0         0
# 12649  202101030tam  WR     Scott Miller  TAM         0         0         0
#
# ...
