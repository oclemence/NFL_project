# %%
import pandas as pd
nfl = "../Data/nfl_elo_all.csv"
pd.read_csv(nfl)
# Out:
#              date  season  neutral playoff team1 team2     elo1_pre  \
# 0      26/09/1920    1920        0     NaN   RII   STP  1503.947000
# 1      03/10/1920    1920        0     NaN   CBD   PTQ  1504.688000
# 2      03/10/1920    1920        0     NaN   CHI   MUT  1368.333000
# 3      03/10/1920    1920        0     NaN   RII   MUN  1516.108000
# 4      03/10/1920    1920        0     NaN   DAY   COL  1493.002000
# ...           ...     ...      ...     ...   ...   ...          ...
# 17090  23/01/2022    2021        0       d    TB   LAR  1681.797158
# 17091  23/01/2022    2021        0       d    KC   BUF  1699.470145
# 17092  30/01/2022    2021        0       c    KC   CIN  1713.932369
# 17093  30/01/2022    2021        0       c   LAR    SF  1651.615346
# 17094  13/02/2022    2021        1       s   CIN   LAR  1593.079331
#
#           elo2_pre  elo_prob1  elo_prob2  ...  qb2_game_value  qb1_value_post  \
# ...
